# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.preprocessing import StandardScaler, PolynomialFeatures
from sklearn.model_selection import train_test_split, cross_val_score, GridSearchCV
from sklearn.linear_model import LinearRegression, SGDRegressor
from sklearn.metrics import mean_squared_error, root_mean_squared_error, mean_absolute_error, r2_score
from sklearn.datasets import make_regression

sns.set_theme(style='darkgrid', palette='deep')

# %% [markdown]
# Load and prepare DataFrames

# %%
# Load red wine DF
red_wine_df = pd.read_csv('./wine+quality/winequality-red.csv', delimiter=';')
red_wine_df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %%
# Red wine Dafa Frame info
red_wine_df.info()

# Make shure that the Red wine data frame has no NaN and catogorial values
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1599 non-null   float64
#  1   volatile acidity      1599 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1599 non-null   float64
#  4   chlorides             1599 non-null   float64
#  5   free sulfur dioxide   1599 non-null   float64
#  6   total sulfur dioxide  1599 non-null   float64
#  7   density               1599 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1599 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 150.0 KB

# %%
# Load red wine DF
white_wine_df = pd.read_csv('./wine+quality/winequality-white.csv', delimiter=';')
white_wine_df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.0              0.27         0.36            20.7      0.045
# 1            6.3              0.30         0.34             1.6      0.049
# 2            8.1              0.28         0.40             6.9      0.050
# 3            7.2              0.23         0.32             8.5      0.058
# 4            7.2              0.23         0.32             8.5      0.058
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 45.0                 170.0   1.0010  3.00       0.45
# 1                 14.0                 132.0   0.9940  3.30       0.49
# 2                 30.0                  97.0   0.9951  3.26       0.44
# 3                 47.0                 186.0   0.9956  3.19       0.40
# 4                 47.0                 186.0   0.9956  3.19       0.40
#
#    alcohol  quality
# 0      8.8        6
# 1      9.5        6
# 2     10.1        6
# ...

# %%
# White wine Dafa Frame info
white_wine_df.info()

# Make shure that the White wine data frame has no NaN and catogorial values
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4898 entries, 0 to 4897
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         4898 non-null   float64
#  1   volatile acidity      4898 non-null   float64
#  2   citric acid           4898 non-null   float64
#  3   residual sugar        4898 non-null   float64
#  4   chlorides             4898 non-null   float64
#  5   free sulfur dioxide   4898 non-null   float64
#  6   total sulfur dioxide  4898 non-null   float64
#  7   density               4898 non-null   float64
#  8   pH                    4898 non-null   float64
#  9   sulphates             4898 non-null   float64
#  10  alcohol               4898 non-null   float64
#  11  quality               4898 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 459.3 KB

# %% [markdown]
# Make statistic and visualize data

# %% [markdown]
# Let look at tagret values for both data frame

# %%
red_wine_df['quality'].value_counts()
# Out:
# quality
# 5    681
# 6    638
# 7    199
# 4     53
# 8     18
# 3     10
# Name: count, dtype: int64

# %%
# Visualize quality targets fow red wine 
sns.kdeplot(red_wine_df['quality'], fill=True, label='Red wine quality')
# Out:
# <Axes: xlabel='quality', ylabel='Density'>

# %%
white_wine_df['quality'].value_counts()
# Out:
# quality
# 6    2198
# 5    1457
# 7     880
# 8     175
# 4     163
# 3      20
# 9       5
# Name: count, dtype: int64

# %%
# Visualize quality targets fow white wine 
sns.kdeplot(white_wine_df['quality'], fill=True, label='White wine quality')
# Out:
# <Axes: xlabel='quality', ylabel='Density'>

# %% [markdown]
# There we can see that the targets with bad and good quality (1, 2, 9, 10) almost is absent, data is not enougth and this case is not good for training model. So we can try to combine two data frame into one big data frame in order to get more precisily training model

# %%
# Combine both data frame into big one
frames = [red_wine_df, white_wine_df]

# Concatenate both data frame
new_df = pd.concat(frames)

new_df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %%
new_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 6497 entries, 0 to 4897
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         6497 non-null   float64
#  1   volatile acidity      6497 non-null   float64
#  2   citric acid           6497 non-null   float64
#  3   residual sugar        6497 non-null   float64
#  4   chlorides             6497 non-null   float64
#  5   free sulfur dioxide   6497 non-null   float64
#  6   total sulfur dioxide  6497 non-null   float64
#  7   density               6497 non-null   float64
#  8   pH                    6497 non-null   float64
#  9   sulphates             6497 non-null   float64
#  10  alcohol               6497 non-null   float64
#  11  quality               6497 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 659.9 KB

# %% [markdown]
# Create a new features

# %%
# Create a new feature for presice traingin model
new_df['max_acidity'] = new_df['volatile acidity'] + new_df['citric acid']
new_df['max_dioxide'] = new_df['total sulfur dioxide']/new_df['free sulfur dioxide']

new_df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality  max_acidity  max_dioxide
# ...

# %% [markdown]
# Create the new two feature for more precise traingin model. Let's look at how to affect it to the correlation of our data frame.

# %% [markdown]
# Create correlation matrix for data frame

# %%
 # Compute the correlation matrix
corr_matrix = new_df.corr()

# Set plot sixe 
plt.figure(figsize=(9, 7))

# Generate a mask for the upper triangle
mask = np.triu(np.ones_like(corr_matrix, dtype=bool))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(230, 20, as_cmap=True)
    
# Visualize correlation matrix
sns.heatmap(corr_matrix, mask=mask, cmap=cmap, annot=True, annot_kws={"fontsize":11})

# Show plot
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# In the heatplot we can see that correlation values don't affect to training model, in fact. Therefor leave it witout changes and can focus on the training model.

# %%
g = sns.PairGrid(new_df, corner=True, diag_sharey=False)
g.map_lower(sns.scatterplot, s=15)
g.map_diag(sns.kdeplot, lw=2)
# sns.pairplot(new_df.sample(frac=0.2, random_state=42), corner=True, kind='reg', diag_kind='kde')

# %% [markdown]
# In the Grid above we can observe some minimal dependencies of feature and outlayers, but in general it won't be affected to result. Let see and if it happen return back to it.

# %% [markdown]
# Training model

# %%
# Preparing data for training and test model
# Create a scaler 
scaler = StandardScaler()

# Fit data scaler variable
data_scaler = scaler.fit_transform(new_df.drop(columns='quality'))

# Split train and test chank 
X_train, X_test, y_train, y_test = train_test_split(data_scaler, new_df.quality, train_size=.7, random_state=42, shuffle=True, stratify=new_df['quality'])

# %% [markdown]
# We split out the data frame on train and test data in proportion for train 0.7 and 0.3 for test part accordingly.

# %% [markdown]
# Linear Regression

# %% [markdown]
# Create and Train the Model

# %%
# Create the linear regression model
linear_reg = LinearRegression()

# Perform 4-fold cross validation 
cv_sc = cross_val_score(linear_reg, X_train, y_train, cv=4)
print(f"Cross-Validation Scores: {cv_sc}")
# Out:
# Cross-Validation Scores: [0.30882795 0.30352645 0.29781394 0.30742552]

# %%
linear_reg.fit(X_train, y_train)

print(f'Train Score: {linear_reg.score(X_train, y_train)}')
print(f'Test Score: {linear_reg.score(X_test, y_test)}')
# Out:
# Train Score: 0.3115519886793615
# Test Score: 0.2927131985072786

# %% [markdown]
# Train with the default hyperparameters show not bad result and show that model is stable.

# %% [markdown]
# Evaluate the Model

# %%
# Fucn for evaluation model
def error_est(model, X_train, X_test, y_train, y_test):
    y_train_pred = np.around(model.predict(X_train), 0)
    y_test_pred = np.around(model.predict(X_test), 0)

    return {
        "MSE Train": round(mean_squared_error(y_train, y_train_pred), 3),
        "MSE Test": round(mean_squared_error(y_test, y_test_pred), 3),
        "RMSE Train": round(root_mean_squared_error(y_train, y_train_pred), 3),
        "RMSE Test": round(root_mean_squared_error(y_test, y_test_pred), 3),
        "MAE Train": round(mean_absolute_error(y_train, y_train_pred), 3),
        "MAE Test": round(mean_absolute_error(y_test, y_test_pred), 3),
    }

error_est(linear_reg, X_train, X_test, y_train, y_test)
# Out:
# {'MSE Train': 0.616,
#  'MSE Test': 0.631,
#  'RMSE Train': 0.785,
#  'RMSE Test': 0.795,
#  'MAE Train': 0.51,
#  'MAE Test': 0.526}

# %% [markdown]
# We observed much higher error than expected, but their are within acceptable bounds. Suppose due to not enough bad and good quality data we have such a big coefficient error.
# Test errors are bigger than test and it's mean that everything is ok, and our model is not overfitting.

# %%
# Visualize our result
sns.kdeplot(y_test, fill=True, label='real')
sns.kdeplot(np.around(linear_reg.predict(X_test), 0), fill=True, label='pred')
plt.legend()

# %% [markdown]
# The model has clear outliers in quality 5-7, but overall the values ​​match the real ones quite well. The model did not capture the extreme quality values

# %% [markdown]
# Stochastic Gradient Descent Regressor

# %%
sgd_reg = SGDRegressor(penalty='elasticnet')
# penalty elasticnet поєднує в собі l1 i l2 регуляризацію
param_grid = {
    'alpha': np.linspace(0.001, 2, 100),
    'l1_ratio': np.linspace(0.01, 0.99, 10),
    'random_state': [17, 42],
}
grid_search_cv = GridSearchCV(sgd_reg, param_grid, cv=4, scoring='neg_mean_squared_error')
grid_search_cv.fit(X_train, y_train)
best_model = grid_search_cv.best_estimator_



print("Best Model:", best_model)

error_est(best_model, X_train, X_test, y_train, y_test)
# Out:
# Best Model: SGDRegressor(alpha=0.001, l1_ratio=0.01, penalty='elasticnet', random_state=17)
# {'MSE Train': 0.622,
#  'MSE Test': 0.633,
#  'RMSE Train': 0.788,
#  'RMSE Test': 0.796,
#  'MAE Train': 0.518,
#  'MAE Test': 0.529}

# %% [markdown]
# Visualize result

# %%
y_train_pred = np.around(best_model.predict(X_train), 0)
y_test_pred = np.around(best_model.predict(X_test), 0)
sns.kdeplot(y_test, fill=True, label='test-real')
sns.kdeplot(y_test_pred, fill=True, label='test-pred')
sns.kdeplot(y_train, fill=True, label='train-real')
sns.kdeplot(y_train_pred, fill=True, label='train-pred')
plt.legend()

# %% [markdown]
# In the SGDRegressor plot we can observe almost the same result as on the previous linear model. The errors are within acceptable bounds and are equal as linear model.
